# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Colab Notebooks/NNTI/NNTI_CV_project/task3
# Out:
# /content/drive/MyDrive/Colab Notebooks/NNTI/NNTI_CV_project/Task3_ver2

# %%
ls
# Out:
# data/           main.py       README.md     task3_ver2.ipynb
# dataaugment.py  model/        runs/         test.py
# dataloader.py   __pycache__/  savedmodels/  utils.py

# %%
from importlib import reload
# %load_ext autoreload
# %autoreload 2

# %%
# !nvidia-smi
# Out:
# Wed Mar  9 20:05:37 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P0    29W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install tensorboardX
# Out:
# ...
#      |████████████████████████████████| 125 kB 8.3 MB/s
# ...

# %%
# %reload_ext tensorboard
# %tensorboard --logdir ./

# %%
# !python -Wignore main.py --threshold 0.95 --num-labeled 2500 --dataset 'cifar100' --lr 0.01 --datapath './data/'
# Out:
# Files already downloaded and verified
# ###
# 0.95
# 2500
# cifar100
# Epoch: 1 : Alpha Weight : 0.00000 | Test Acc : 11.83000 | Test Loss : 4.563
# test accuracy increased (0.000000 --> 11.830000).  Saving model ...
# Epoch: 2 : Alpha Weight : 0.05000 | Test Acc : 14.34000 | Test Loss : 4.530
# test accuracy increased (11.830000 --> 14.340000).  Saving model ...
# Epoch: 3 : Alpha Weight : 0.10000 | Test Acc : 16.18000 | Test Loss : 4.498
# test accuracy increased (14.340000 --> 16.180000).  Saving model ...
# Epoch: 4 : Alpha Weight : 0.15000 | Test Acc : 17.05000 | Test Loss : 4.478
# test accuracy increased (16.180000 --> 17.050000).  Saving model ...
# Epoch: 5 : Alpha Weight : 0.20000 | Test Acc : 18.19000 | Test Loss : 4.452
# test accuracy increased (17.050000 --> 18.190000).  Saving model ...
# Epoch: 6 : Alpha Weight : 0.25000 | Test Acc : 18.74000 | Test Loss : 4.447
# test accuracy increased (18.190000 --> 18.740000).  Saving model ...
# ...
