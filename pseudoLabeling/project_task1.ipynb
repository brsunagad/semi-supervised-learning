# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Colab Notebooks/NNTI/NNTI_CV_project/Task1_pseudoLabeling
# Out:
# /content/drive/MyDrive/Colab Notebooks/NNTI/NNTI_CV_project/Task1_pseudoLabeling

# %%
ls
# Out:
# data/          model_cifar10_4000_0.95.pth.tar  README.md
# dataloader.py  model.pth.tar                    savedmodels/
# main.py        project_task1.ipynb              test.py
# model/         __pycache__/                     utils.py

# %%
from importlib import reload
# %load_ext autoreload
# %autoreload 2

# %%
# !nvidia-smi
# Out:
# Mon Feb 28 07:53:40 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !python -Wignore main.py --num-workers 8 --threshold 0.95 --num-labeled 2500 --dataset 'cifar100'
# Out:
# Files already downloaded and verified
# 0.75
# 2500
# cifar100
# Epoch: 5 : Alpha Weight : 0.00000 | Test Acc : 25.06000 | Test Loss : 4.391
# test accuracy increased (0.000000 --> 25.060000).  Saving model ...
# Epoch: 10 : Alpha Weight : 0.00000 | Test Acc : 28.04000 | Test Loss : 4.358
# test accuracy increased (25.060000 --> 28.040000).  Saving model ...
# Epoch: 15 : Alpha Weight : 0.00000 | Test Acc : 27.57000 | Test Loss : 4.357
# Epoch: 20 : Alpha Weight : 0.00000 | Test Acc : 22.54000 | Test Loss : 4.405
# Epoch: 25 : Alpha Weight : 0.71429 | Test Acc : 26.16000 | Test Loss : 4.366
# Epoch: 30 : Alpha Weight : 1.42857 | Test Acc : 26.66000 | Test Loss : 4.359
# Epoch: 35 : Alpha Weight : 2.14286 | Test Acc : 28.68000 | Test Loss : 4.340
# test accuracy increased (28.040000 --> 28.680000).  Saving model ...
# Epoch: 40 : Alpha Weight : 2.85714 | Test Acc : 25.69000 | Test Loss : 4.366
# Epoch: 45 : Alpha Weight : 3.00000 | Test Acc : 27.80000 | Test Loss : 4.346
# ...
